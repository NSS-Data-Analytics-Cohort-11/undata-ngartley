# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
gdp_df = pd.read_csv('../data/gdp_percapita.csv')

# %% [markdown]
# ## Question 4

# %%
#Looking at the top 5
gdp_df.head()
# Out:
#   Country or Area  Year        Value  Value Footnotes
# 0     Afghanistan  2021  1517.016266              NaN
# 1     Afghanistan  2020  1968.341002              NaN
# 2     Afghanistan  2019  2079.921861              NaN
# 3     Afghanistan  2018  2060.698973              NaN
# 4     Afghanistan  2017  2096.093111              NaN

# %%
### looking at the bottom 52
gdp_df.tail()
# Out:
#      Country or Area  Year        Value  Value Footnotes
# 7657        Zimbabwe  1994  2670.106615              NaN
# 7658        Zimbabwe  1993  2458.783255              NaN
# 7659        Zimbabwe  1992  2468.278257              NaN
# 7660        Zimbabwe  1991  2781.787843              NaN
# 7661        Zimbabwe  1990  2704.757299              NaN

# %% [markdown]
# ## Question 5

# %%
#Rows? Columns?.0
gdp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7662 entries, 0 to 7661
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country or Area  7662 non-null   object
#  1   Year             7662 non-null   int64
#  2   Value            7662 non-null   float64
#  3   Value Footnotes  0 non-null      float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 239.6+ KB

# %% [markdown]
# ### Answer: 7662 Rows; 4 Columns
# #### Data Types of Columns: Country - Object, Year - Integer, Value - Float, Value Footnotes - Float

# %% [markdown]
# ## Question 6

# %%
#Rename the columns
gdp_df = gdp_df.rename(columns={'Country or Area': 'Country', 'Year': 'Year', 'Value': 'GDP_Per_Capita'})

# %%
#Drop the Value Footnotes Column
gdp_df = gdp_df.drop('Value Footnotes', axis=1)

# %% [markdown]
# ## Question 7

# %%
## Look at country/year

# %%
gdp_cc = gdp_df.groupby(['Country'])['Country'].count().reset_index(name="Years")

# %%
gdp_cc
# Out:
#                          Country  Years
# 0                    Afghanistan     20
# 1    Africa Eastern and Southern     33
# 2     Africa Western and Central     33
# 3                        Albania     33
# 4                        Algeria     33
# ..                           ...    ...
# 237                     Viet Nam     33
# 238           West Bank and Gaza     29
# 239                        World     33
# 240                       Zambia     33
# 241                     Zimbabwe     33
#
# [242 rows x 2 columns]

# %%
gdp_cc2= gdp_df["Country"].value_counts(sort=True)

# %%
gdp_cc2
# Out:
# Country
# Least developed countries: UN classification    33
# Middle East & North Africa                      33
# Middle East & North Africa (IDA & IBRD)         33
# Middle income                                   33
# Mongolia                                        33
#                                                 ..
# Kosovo                                          15
# Sint Maarten (Dutch part)                       14
# Turks and Caicos Islands                        12
# Somalia                                         10
# Djibouti                                        10
# Name: count, Length: 242, dtype: int64

# %% [markdown]
# ## Question 8

# %%
gdp_2000 = gdp_df[gdp_df["Year"] == 2000]

# %%
print(gdp_2000)
# Out:
#                           Country  Year  GDP_Per_Capita
# 42    Africa Eastern and Southern  2000     2897.140841
# 75     Africa Western and Central  2000     2671.599188
# 108                       Albania  2000     5892.582191
# 141                       Algeria  2000     8786.190350
# 174                        Angola  2000     4728.374368
# ...                           ...   ...             ...
# 7523                     Viet Nam  2000     3690.868166
# 7556           West Bank and Gaza  2000     4503.248849
# 7585                        World  2000    11114.642436
# 7618                       Zambia  2000     2096.490412
# 7651                     Zimbabwe  2000     2750.601236
#
# [233 rows x 3 columns]

# %%
sns.histplot(data=gdp_2000, y= "GDP_Per_Capita", bins=20)
# Out:
# C:\Users\nyssa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Count', ylabel='GDP_Per_Capita'>

# %%
sns.kdeplot(gdp_2000["GDP_Per_Capita"])
# Out:
# C:\Users\nyssa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='GDP_Per_Capita', ylabel='Density'>

# %%
sns.boxplot(x=gdp_2000["GDP_Per_Capita"])
# Out:
# <Axes: xlabel='GDP_Per_Capita'>

# %%
sns.violinplot(x=gdp_2000["GDP_Per_Capita"])
# Out:
# <Axes: xlabel='GDP_Per_Capita'>

# %% [markdown]
# ## Question 9

# %% [markdown]
# Median GDP Per Capita in 2000

# %%
gdp_2000["GDP_Per_Capita"].median()
# Out:
# 8702.082651105855

# %% [markdown]
# ## Question 10

# %% [markdown]
# ## Question 11

# %% [markdown]
# Which country was the first to have a GDP per capita greater than $100,000?

# %%
gdp_over100K = gdp_df[gdp_df["GDP_Per_Capita"]>100000]

# %%
gdp_over100K.sort_values(("GDP_Per_Capita"), ascending=(True))
# Out:
#                    Country  Year  GDP_Per_Capita
# 7295  United Arab Emirates  1997   100956.706467
# 7301  United Arab Emirates  1991   101048.696239
# 4167            Luxembourg  2001   101143.147977
# 5751                 Qatar  2015   101971.989608
# 3278               Ireland  2021   102785.490239
# 4166            Luxembourg  2002   103317.331098
# 5756                 Qatar  2010   103902.519310
# 4165            Luxembourg  2003   104743.000088
# 7302  United Arab Emirates  1990   105893.626059
# 5752                 Qatar  2014   106141.326189
# 4164            Luxembourg  2004   107634.837198
# 6107             Singapore  2021   107741.118436
# 6106             Singapore  2022   108036.110993
# 4163            Luxembourg  2005   108632.360016
# 5753                 Qatar  2013   109625.629601
# 5754                 Qatar  2012   110931.506472
# 4148            Luxembourg  2020   111751.314751
# 5755                 Qatar  2011   111879.747777
# ...

# %% [markdown]
# Looks as though it was UAE in 1990.

# %% [markdown]
# ## Question 12

# %% [markdown]
# Which country had the highest GDP per capita in 2020? Create a plot showing how this country's GDP per capita has changed over the timespan of the dataset.

# %%
gdp_2020 = gdp_df[gdp_df["Year"] == 2020]

# %%
gdp_2020.sort_values(("GDP_Per_Capita"), ascending=(False))
# Out:
#                        Country  Year  GDP_Per_Capita
# 4148                Luxembourg  2020   111751.314751
# 6108                 Singapore  2020    94910.101431
# 3279                   Ireland  2020    91356.855054
# 5746                     Qatar  2020    89019.069857
# 681                    Bermuda  2020    76117.804744
# ...                        ...   ...             ...
# 5074                     Niger  2020     1214.546556
# 6273                   Somalia  2020     1127.418534
# 1630           Dem. Rep. Congo  2020     1044.071214
# 1217  Central African Republic  2020      847.765012
# 973                    Burundi  2020      711.355263
#
# [242 rows x 3 columns]

# %%
lux = gdp_df[gdp_df["Country"] == "Luxembourg"]

# %%
lux
# Out:
#          Country  Year  GDP_Per_Capita
# 4146  Luxembourg  2022   115541.774828
# 4147  Luxembourg  2021   115683.493708
# 4148  Luxembourg  2020   111751.314751
# 4149  Luxembourg  2019   114542.496934
# 4150  Luxembourg  2018   114164.468558
# 4151  Luxembourg  2017   114985.842236
# 4152  Luxembourg  2016   116283.699681
# 4153  Luxembourg  2015   113182.728563
# 4154  Luxembourg  2014   113313.578898
# 4155  Luxembourg  2013   113050.663254
# 4156  Luxembourg  2012   112137.135491
# 4157  Luxembourg  2011   112998.390477
# 4158  Luxembourg  2010   114343.988089
# 4159  Luxembourg  2009   112230.081410
# 4160  Luxembourg  2008   118154.667184
# 4161  Luxembourg  2007   120647.822959
# 4162  Luxembourg  2006   113346.035782
# 4163  Luxembourg  2005   108632.360016
# 4164  Luxembourg  2004   107634.837198
# 4165  Luxembourg  2003   104743.000088
# 4166  Luxembourg  2002   103317.331098
# 4167  Luxembourg  2001   101143.147977
# 4168  Luxembourg  2000    99301.526999
# ...

# %%
sns.lineplot(data=lux, x="Year", y="GDP_Per_Capita")
# Out:
# C:\Users\nyssa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nyssa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %% [markdown]
# ## Question 13

# %% [markdown]
# Which country had the lowest GDP per capita in 2020? Create a plot showing how this country's GDP per capita has changed over the timespan of the dataset.

# %%
gdp_2020.sort_values(("GDP_Per_Capita"), ascending=(True))
# Out:
#                        Country  Year  GDP_Per_Capita
# 973                    Burundi  2020      711.355263
# 1217  Central African Republic  2020      847.765012
# 1630           Dem. Rep. Congo  2020     1044.071214
# 6273                   Somalia  2020     1127.418534
# 5074                     Niger  2020     1214.546556
# ...                        ...   ...             ...
# 681                    Bermuda  2020    76117.804744
# 5746                     Qatar  2020    89019.069857
# 3279                   Ireland  2020    91356.855054
# 6108                 Singapore  2020    94910.101431
# 4148                Luxembourg  2020   111751.314751
#
# [242 rows x 3 columns]

# %%
bur = gdp_df[gdp_df["Country"] == "Burundi"]

# %%
bur
# Out:
#       Country  Year  GDP_Per_Capita
# 971   Burundi  2022      708.178317
# 972   Burundi  2021      714.066712
# 973   Burundi  2020      711.355263
# 974   Burundi  2019      729.658463
# 975   Burundi  2018      740.448223
# 976   Burundi  2017      750.787616
# 977   Burundi  2016      764.336602
# 978   Burundi  2015      781.579287
# 979   Burundi  2014      831.294839
# 980   Burundi  2013      824.610523
# 981   Burundi  2012      814.320771
# 982   Burundi  2011      807.664958
# 983   Burundi  2010      804.354941
# 984   Burundi  2009      801.803427
# 985   Burundi  2008      812.592170
# 986   Burundi  2007      807.447481
# 987   Burundi  2006      809.696011
# 988   Burundi  2005      796.108713
# 989   Burundi  2004      818.746063
# 990   Burundi  2003      810.552335
# 991   Burundi  2002      846.747295
# 992   Burundi  2001      833.670879
# 993   Burundi  2000      837.348411
# 994   Burundi  1999      862.006680
# 995   Burundi  1998      891.699844
# ...

# %%
sns.lineplot(data=bur, x="Year", y="GDP_Per_Capita")
# Out:
# C:\Users\nyssa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\nyssa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Year', ylabel='GDP_Per_Capita'>

# %% [markdown]
# ## Question 14

# %%
internet_use = pd.read_csv('../data/internet_use.csv', nrows=4495)

# %%
internet_use
# Out:
#      Country or Area  Year     Value  Value Footnotes
# 0        Afghanistan  2014  6.390000              NaN
# 1        Afghanistan  2013  5.900000              NaN
# 2        Afghanistan  2012  5.454545              NaN
# 3        Afghanistan  2011  5.000000              NaN
# 4        Afghanistan  2010  4.000000              NaN
# ...              ...   ...       ...              ...
# 4490        Zimbabwe  1997  0.033080              NaN
# 4491        Zimbabwe  1996  0.016790              NaN
# 4492        Zimbabwe  1995  0.007684              NaN
# 4493        Zimbabwe  1994  0.001739              NaN
# 4494        Zimbabwe  1990  0.000000              NaN
#
# [4495 rows x 4 columns]

# %% [markdown]
# ## Question 15

# %%
#Rename the columns
internet_use = internet_use.rename(columns={'Country or Area': 'Country', 'Year': 'Year', 'Value': 'Internet_Users_Pct'})
internet_use = internet_use.drop('Value Footnotes', axis=1)

# %%
internet_use
# Out:
#           Country  Year  Internet_Users_Pct
# 0     Afghanistan  2014            6.390000
# 1     Afghanistan  2013            5.900000
# 2     Afghanistan  2012            5.454545
# 3     Afghanistan  2011            5.000000
# 4     Afghanistan  2010            4.000000
# ...           ...   ...                 ...
# 4490     Zimbabwe  1997            0.033080
# 4491     Zimbabwe  1996            0.016790
# 4492     Zimbabwe  1995            0.007684
# 4493     Zimbabwe  1994            0.001739
# 4494     Zimbabwe  1990            0.000000
#
# [4495 rows x 3 columns]

# %% [markdown]
# ## Question 16

# %% [markdown]
# Look at the number of observations in this dataset per year. What do you notice?
